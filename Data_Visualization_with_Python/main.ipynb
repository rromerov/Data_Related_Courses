# %% [markdown]
# <a href="https://colab.research.google.com/github/rromerov/Data_Related_Courses/blob/main/Data_Visualization_with_Python/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Visualization with Python

# %% [markdown]
# ## Why Build Visuals?
#
# 1. For exploratory data analysis
#
# 2. Communicate data clearly
#
# 3. Share unbiased representation of data
#
# 4. Use them to support recommendations to different stakeholders

# %% [markdown]
# ## Best Practices
#
# When creating a visual, always remember:
#
# 1. Less is more effective
#
# 2. Less is more attractive
#
# 3. Less is more impactive

# %% [markdown]
# ## Comparison

# %% [markdown]
# ### Bad

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Good

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# As it can be seen, less is more, in this case if we are more interested in knowing more about bacon, it's clear that we need to focus our attention on that. By doing the graph more simple, it's much easier to understand.

# %% [markdown]
# **Bar charts and graphs are argued to be far superior ways to quickly get a message than a pie chart.**

# %% [markdown]
# # Matplotlib

# %% [markdown]
# ## Artist Layer
#
# Composed of title, lines, tick labels, and images
#
# Let's generate a histogram using the artist layer:

# %%
from matplotlib.backends.backend_agg import FigureCanvasAgg as FigureCanvas
from matplotlib.figure import Figure
fig=Figure()
canvas=FigureCanvas(fig)

#generate random numbers

import numpy as np

x=np.random.randn(10000)

ax=fig.add_subplot(111) #create an axes artist

ax.hist(x,100) #generate a histogram of the 1000 numbers

#add a title to the figure and save it
ax.set_title("Normal distribution with $\mu=0, \sigma=1$") #latex
fig.savefig("matplotlib_histogram.png")

# %% [markdown]
# The code below is intended for developers, not for individuals whose goal is to perform quickly exploratory analysis.
#
# For that it's used the:
#
# ## Scripting Layer
#
# * Comprised mainly of **pyplot**, a scripting interface that is lighter that the **Artist** layer.
#
# * Know let's compare the scripting layer vs the artist layer:
